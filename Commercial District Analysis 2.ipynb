# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

plt.rc("font", family="AppleGothic")
plt.rc("axes", unicode_minus=False)
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

df = pd.read_csv('df_modified.csv')

# %% [markdown]
# ## 6. Multi-index Reformation

# %% [markdown]
# ### by Pandas Stack and Unstack

# %%
g = df_academy_selected.groupby(["Specialty", "District"])["Store Name"].count()
g.head()
# Out:
# Specialty  District
# 고시원        Dobong-gu         8
#            Dongdaemun-gu    69
#            Dongjak-gu       79
#            Eunpyeong-gu     12
#            Gangbuk-gu       11
# Name: Store Name, dtype: int64

# %%
g.unstack().iloc[:5, :5]
# Out:
# District     Dobong-gu  Dongdaemun-gu  Dongjak-gu  Eunpyeong-gu  Gangbuk-gu
# Specialty
# 고시원                  8             69          79            12          11
# 독서실                 30             31          95            48          14
# 서예/서화/미술            25             61          41            55          19
# 어린이집               194            144         148           228         112
# 피아노/바이올린/기타         58             94          75           116          47

# %%
g.unstack().T.iloc[:5, :5]
# Out:
# Specialty      고시원  독서실  서예/서화/미술  어린이집  피아노/바이올린/기타
# District
# Dobong-gu        8   30        25   194           58
# Dongdaemun-gu   69   31        61   144           94
# Dongjak-gu      79   95        41   148           75
# Eunpyeong-gu    12   48        55   228          116
# Gangbuk-gu      11   14        19   112           47

# %%
g.unstack()
# Out:
# District     Dobong-gu  Dongdaemun-gu  Dongjak-gu  Eunpyeong-gu  Gangbuk-gu  \
# Specialty
# 고시원                  8             69          79            12          11
# 독서실                 30             31          95            48          14
# 서예/서화/미술            25             61          41            55          19
# 어린이집               194            144         148           228         112
# 피아노/바이올린/기타         58             94          75           116          47
# 학원(종합)             183            190         131           203         101
# 학원-외국어/어학          112             87          81           163          37
# 학원-입시              239            187         227           337         103
#
# District     Gangdong-gu  Gangnam-gu  Gangseo-gu  Geumcheon-gu  Guro-gu  ...  \
# Specialty                                                                ...
# 고시원                   62         139          32            24       33  ...
# ...

# %%
g.unstack().plot.barh(figsize=(8,9))
# Out:
# <AxesSubplot:ylabel='Specialty'>

# %%
g.unstack().loc["학원-입시"].plot.barh(figsize=(8,9))
# Out:
# <AxesSubplot:ylabel='District'>

# %%
g.unstack().T.plot.bar(figsize=(15,5), rot=30)
# Out:
# <AxesSubplot:xlabel='District'>

# %% [markdown]
# ### by Seaborn

# %%
plt.figure(figsize=(15,4))
sb.barplot(data=t, x="District",y="Number")
# Out:
# <AxesSubplot:xlabel='District', ylabel='Number'>

# %% [markdown]
# ## 7. Visualization by 'Latitude' and 'Longitude'

# %%
plt.figure(figsize=(8,7))
sb.scatterplot(data=df_seoul_food, x="Longitude", y="Latitude", hue="District")
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
plt.figure(figsize=(8,7))
sb.scatterplot(data=df_seoul_food, x="Longitude", y="Latitude", hue="Subtype")
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
plt.figure(figsize=(8,7))
sb.scatterplot(data=df_seoul_food[df_seoul_food["Subtype"].isin(["Caffe/Tea","Bread/Cake/Cookie"])],
               x="Longitude", y="Latitude", hue="Subtype")
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>
